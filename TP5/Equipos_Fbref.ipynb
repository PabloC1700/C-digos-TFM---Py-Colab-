# %% [markdown]
# <a href="https://colab.research.google.com/github/PabloC1700/C-digos-TFM---Py-Colab-/blob/main/TP5/Equipos_Fbref.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install LanusStats

# %%
import LanusStats as ls

# %%
ls.get_available_pages()
# Out:
# dict_keys(['Fbref', 'Sofascore', '365Scores', 'Fotmob'])

# %%
ls.get_available_leagues('Fbref')
# Out:
# ['Copa de la Liga',
#  'Primera Division Argentina',
#  'Primera Division Uruguay',
#  'Brasileirao',
#  'Brasileirao B',
#  'Primera Division Colombia',
#  'Primera Division Chile',
#  'Primera Division Peru',
#  'Primera Division Venezuela',
#  'Primera Division Ecuador',
#  'Primera Division Bolivia',
#  'Primera Division Paraguay',
#  'Brasileirao F',
#  'MLS',
#  'USL Championship',
#  'Premier League',
#  'La Liga',
#  'Ligue 1',
#  'Bundesliga',
#  'Serie A',
#  'Big 5 European Leagues',
#  'Danish Superliga',
#  'Eredivise',
#  'Primeira Liga Portugal']

# %%
ls.get_available_season_for_leagues('Fbref','Serie A')
# Out:
# {'id': 11,
#  'slug': 'Serie-A',
#  'seasons': {'2020-2021', '2021-2022', '2022-2023', '2023-2024'}}

# %%
Fbref= ls.Fbref()

# %%
Fbref.get_teams_season_stats('stats','Serie A','2022-2023')
# Out:
# Starting to scrape teams data from Fbref...
#             Squad  # Pl   Age  Poss  MP  Starts   Min   90s  Gls  Ast  ...  \
# 0        Atalanta    27  26.5  49.9  38     418  3420  38.0   64   42  ...
# 1         Bologna    27  26.6  54.7  38     418  3420  38.0   52   41  ...
# 2       Cremonese    33  26.0  42.1  38     418  3420  38.0   35   18  ...
# 3          Empoli    32  25.3  47.3  38     418  3420  38.0   35   20  ...
# 4      Fiorentina    30  26.5  56.1  38     418  3420  38.0   51   37  ...
# 5   Hellas Verona    36  26.6  41.2  38     418  3420  38.0   29   22  ...
# 6           Inter    25  28.8  55.7  38     418  3420  38.0   68   50  ...
# 7        Juventus    29  27.7  49.6  38     418  3420  38.0   56   41  ...
# 8           Lazio    24  28.6  52.1  38     418  3420  38.0   59   37  ...
# 9           Lecce    29  24.8  41.3  38     418  3420  38.0   31   21  ...
# 10          Milan    30  26.0  55.6  38     418  3420  38.0   61   49  ...
# ...

# %%
Fbref.get_teams_season_stats('shooting','Serie A','2022-2023')
# Out:
# Starting to scrape teams data from Fbref...
#             Squad  # Pl   90s  Gls   Sh  SoT  SoT%  Sh/90  SoT/90  G/Sh  \
# 0        Atalanta    27  38.0   64  506  168  33.2  13.32    4.42  0.11
# 1         Bologna    27  38.0   52  479  150  31.3  12.61    3.95  0.10
# 2       Cremonese    33  38.0   35  458  122  26.6  12.05    3.21  0.07
# 3          Empoli    32  38.0   35  447  129  28.9  11.76    3.39  0.07
# 4      Fiorentina    30  38.0   51  597  171  28.6  15.71    4.50  0.08
# 5   Hellas Verona    36  38.0   29  415  116  28.0  10.92    3.05  0.07
# 6           Inter    25  38.0   68  625  197  31.5  16.45    5.18  0.10
# 7        Juventus    29  38.0   56  529  171  32.3  13.92    4.50  0.10
# 8           Lazio    24  38.0   59  430  161  37.4  11.32    4.24  0.12
# 9           Lecce    29  38.0   31  412  106  25.7  10.84    2.79  0.07
# 10          Milan    30  38.0   61  546  178  32.6  14.37    4.68  0.10
# ...

# %%
Fbref.get_teams_season_stats('passing','Serie A','2022-2023')
# Out:
# Starting to scrape teams data from Fbref...
#             Squad  # P
# Out:
# Starting to scrape teams data from Fbref...
#             Squad  # Pl  Poss   90s  Touches  Def Pen  Def 3rd  Mid 3rd  \
# 0        Atalanta    27  49.9  38.0    23862     2217     7478    10221
# 1         Bologna    27  54.7  38.0    24552     2551     8483    11383
# 2       Cremonese    33  42.1  38.0    19346     2538     7184     8051
# 3          Empoli    32  47.3  38.0    21188     2962     8175     8766
# 4      Fiorentina    30  56.1  38.0    23123     2028     6652    10361
# 5   Hellas Verona    36  41.2  38.0    18056     2231     6320     7844
# 6           Inter    25  55.7  38.0    25128     2720     8300    11127
# 7        Juventus    29  49.6  38.0    22810     2432     7514    10435
# 8           Lazio    24  52.1  38.0    25453     2536     8100    12315
# 9           Lecce    29  41.3  38.0    18839     2129     6291     8105
# 10          Milan    30  55.6  38.0    23856     2177     7373    11143
# ...

# %%
Fbref.get_teams_season_stats('playingtime','Serie A','2022-2023')
# Out:
# Starting to scrape teams data from Fbref...
#             Squad  # Pl   Age  MP   Min  Mn/MP  Min%   90s  Starts  Mn/Start  \
# 0        Atalanta    27  26.5  38  3420     90   100  38.0     418        80
# 1         Bologna    27  26.6  38  3420     90   100  38.0     418        81
# 2       Cremonese    33  26.0  38  3420     90   100  38.0     418        79
# 3          Empoli    32  25.3  38  3420     90   100  38.0     418        80
# 4      Fiorentina    30  26.5  38  3420     90   100  38.0     418        79
# 5   Hellas Verona    36  26.6  38  3420     90   100  38.0     418        79
# 6           Inter    25  28.8  38  3420     90   100  38.0     418        81
# 7        Juventus    29  27.7  38  3420     90   100  38.0     418        81
# 8           Lazio    24  28.6  38  3420     90   100  38.0     418        82
# 9           Lecce    29  24.8  38  3420     90   100  38.0     418        81
# 10          Milan    30  26.0  38  3420     90   100  38.0     418        80
# ...

# %%
Fbref.get_teams_season_stats('misc','Serie A','2022-2023')
# Out:
# Starting to scrape teams data from Fbref...
#             Squad  # Pl   90s  CrdY  CrdR  2CrdY  Fls  Fld  Off  Crs  Int  \
# 0        Atalanta    27  38.0    83     3      1  470  385   58  652  421
# 1         Bologna    27  38.0    84     3      2  477  426   77  558  302
# 2       Cremonese    33  38.0    81     3      0  458  407   68  659  393
# 3          Empoli    32  38.0    88     7      3  441  459   54  611  280
# 4      Fiorentina    30  38.0    93     3      2  488  511   56  880  260
# 5   Hellas Verona    36  38.0   103     3      0  540  383   74  652  337
# 6           Inter    25  38.0    65     3      2  444  406   68  885  315
# 7        Juventus    29  38.0    74     6      1  456  409   62  731  307
# 8           Lazio    24  38.0    87     2      0  400  471   54  483  310
# 9           Lecce    29  38.0    86     2      1  553  439   68  709  368
# 10          Milan    30  38.0    90     2      2  449  438   61  671  289
# ...

# %%
pip install openpyxl

# %%
import pandas as pd
import os

# Lista de nombres de tablas
table_names = ['stats', 'keepers', 'keepersadv', 'shooting','passing','passing_types', 'gca', 'defense', 'possession', 'playingtime', 'misc']

# Diccionario para almacenar los DataFrames
dataframes = {}

# Suponiendo que usas fbref.get_player_season_stats para obtener los DataFrames
# Cargar las tablas en el diccionario
for table_name in table_names:
    dataframes[table_name] = Fbref.get_teams_season_stats(table_name, 'Serie A', '2023-2024')

# Definir el nombre del archivo Excel
file_path = 'Serie A_2324 - FBREF Equipos.xlsx'

# Escribir los DataFrames a un archivo Excel con diferentes hojas
with pd.ExcelWriter(file_path, engine='openpyxl') as writer:
    for sheet_name, dataframe in dataframes.items():
        dataframe.to_excel(writer, sheet_name=sheet_name, index=False)

print("Archivo Excel guardado con éxito.")
# Out:
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
# Starting to scrape teams data from Fbref...
# Archivo Excel guardado con éxito.
