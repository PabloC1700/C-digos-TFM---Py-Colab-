# %% [markdown]
# <a href="https://colab.research.google.com/github/PabloC1700/C-digos-TFM---Py-Colab-/blob/main/TP2/Radar_Chart_DF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
# !pip install soccerplots
from soccerplots.radar_chart import Radar

# %%
#Read in the data
df = pd.read_csv('Big_5_European_Leagues_Stats.csv')

# %%
df.head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
# 0                 Rk             Player             Nation                Pos
# 1                  1         Max Aarons            eng ENG                 DF
# 2                  2   Brenden Aaronson             us USA              MF,FW
# 3                  3    Paxten Aaronson             us USA                 MF
# 4                  4  Keyliane Abdallah             fr FRA                 FW
#
#   Unnamed: 4_level_0  Unnamed: 5_level_0 Unnamed: 6_level_0  \
# 0              Squad                Comp                Age
# 1        Bournemouth  eng Premier League                 23
# 2       Union Berlin       de Bundesliga                 22
# 3     Eint Frankfurt       de Bundesliga                 19
# 4          Marseille          fr Ligue 1                 17
#
#   Unnamed: 7_level_0 Unnamed: 8_level_0 Tackles  ... Challenges.2  \
# ...

# %%
# Replace the headers with the first row
df.columns = df.iloc[0]
df = df[1:]

# Reset the index
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
# 0 Rk             Player   Nation    Pos           Squad                Comp  \
# 0  1         Max Aarons  eng ENG     DF     Bournemouth  eng Premier League
# 1  2   Brenden Aaronson   us USA  MF,FW    Union Berlin       de Bundesliga
# 2  3    Paxten Aaronson   us USA     MF  Eint Frankfurt       de Bundesliga
# 3  4  Keyliane Abdallah   fr FRA     FW       Marseille          fr Ligue 1
# 4  5   Yunis Abdelhamid   ma MAR     DF           Reims          fr Ligue 1
#
# 0 Age  Born   90s Tkl  ...   Tkl% Lost Blocks  Sh Pass Int Tkl+Int  Clr Err  \
# 0  23  2000  13.7  29  ...   58.8   14      9   5    4   8      37   27   0
# 1  22  2000  14.1  32  ...   50.0   16     26   1   25   2      34    4   0
# 2  19  2003   1.1   2  ...  100.0    0      2   0    2   0       2    0   0
# 3  17  2006   0.0   0  ...    NaN    0      0   0    0   0       0    0   0
# 4  35  1987  30.9  64  ...   57.8   19     51  32   19  39     103  109   2
#
# 0  Matches
# 0  Matches
# 1  Matches
# 2  Matches
# ...

# %%
df['Player'] = df['Player'].str.split('  ',expand=True)[0]

# %%
df.head()
# Out:
# 0 Rk             Player   Nation    Pos           Squad                Comp  \
# 0  1         Max Aarons  eng ENG     DF     Bournemouth  eng Premier League
# 1  2   Brenden Aaronson   us USA  MF,FW    Union Berlin       de Bundesliga
# 2  3    Paxten Aaronson   us USA     MF  Eint Frankfurt       de Bundesliga
# 3  4  Keyliane Abdallah   fr FRA     FW       Marseille          fr Ligue 1
# 4  5   Yunis Abdelhamid   ma MAR     DF           Reims          fr Ligue 1
#
# 0 Age  Born   90s Tkl  ...   Tkl% Lost Blocks  Sh Pass Int Tkl+Int  Clr Err  \
# 0  23  2000  13.7  29  ...   58.8   14      9   5    4   8      37   27   0
# 1  22  2000  14.1  32  ...   50.0   16     26   1   25   2      34    4   0
# 2  19  2003   1.1   2  ...  100.0    0      2   0    2   0       2    0   0
# 3  17  2006   0.0   0  ...    NaN    0      0   0    0   0       0    0   0
# 4  35  1987  30.9  64  ...   57.8   19     51  32   19  39     103  109   2
#
# 0  Matches
# 0  Matches
# 1  Matches
# 2  Matches
# ...

# %%
df.Player.unique()
# Out:
# array(['Max Aarons', 'Brenden Aaronson', 'Paxten Aaronson', ...,
#        'Martin Ødegaard', 'Milan Đurić', 'Mateusz Łęgowski'], dtype=object)

# %%
df = df[(df['Player']=='Emmanuel Agbadou') | (df['Player']=='Joachim Andersen') | (df['Player']=='Facundo Medina') | (df['Player']=='Leonardo Balerdi')].reset_index()

# %%
df
# Out:
# 0  index    Rk            Player  Nation Pos           Squad  \
# 0     33    33  Emmanuel Agbadou  ci CIV  DF           Reims
# 1    109   106  Joachim Andersen  dk DEN  DF  Crystal Palace
# 2    206   200  Leonardo Balerdi  ar ARG  DF       Marseille
# 3   1775  1708    Facundo Medina  ar ARG  DF            Lens
#
# 0                Comp Age  Born   90s  ...  Tkl% Lost Blocks  Sh Pass Int  \
# 0          fr Ligue 1  26  1997  28.8  ...  68.8   20     47  25   22  55
# 1  eng Premier League  27  1996  37.9  ...  74.4   10     33  18   15  41
# 2          fr Ligue 1  24  1999  25.2  ...  73.1   18     38  15   23  51
# 3          fr Ligue 1  24  1999  30.2  ...  63.8   25     38  13   25  24
#
# 0 Tkl+Int  Clr Err  Matches
# 0     120  116   1  Matches
# 1      97  207   1  Matches
# 2     130   91   0  Matches
# 3      88   59   2  Matches
#
# [4 rows x 27 columns]

# %%
df = df.drop(['index','Rk','Nation','Pos','Squad','Comp','Age','Born','90s','Tkl','Err','Matches'],axis=1)

# %%
df
# Out:
# 0            Player TklW Def 3rd Mid 3rd Att 3rd Att  Tkl% Lost Blocks  Sh  \
# 0  Emmanuel Agbadou   41      38      23       4  64  68.8   20     47  25
# 1  Joachim Andersen   35      33      21       2  39  74.4   10     33  18
# 2  Leonardo Balerdi   50      55      23       1  67  73.1   18     38  15
# 3    Facundo Medina   38      25      31       8  69  63.8   25     38  13
#
# 0 Pass Int Tkl+Int  Clr
# 0   22  55     120  116
# 1   15  41      97  207
# 2   23  51     130   91
# 3   25  24      88   59

# %%
#get parameters
params = list(df.columns)
params = params[1:]
params
# Out:
# ['TklW',
#  'Def 3rd',
#  'Mid 3rd',
#  'Att 3rd',
#  'Att',
#  'Tkl%',
#  'Lost',
#  'Blocks',
#  'Sh',
#  'Pass',
#  'Int',
#  'Tkl+Int',
#  'Clr']

# %%
#add ranges to list of tuple pairs
ranges = []
a_values = []
b_values = []
c_values = []
d_values = []

for param in params:
    a = df[param].astype(float).min()
    a = a - (a * 0.25)
    b = df[param].astype(float).max()
    b = b + (b * 0.25)

    ranges.append((a,b))

for x in range(len(df['Player'])):
    if df['Player'][x] == 'Emmanuel Agbadou':
      a_values = df.iloc[x].values.tolist()
    if df['Player'][x] == 'Joachim Andersen':
      b_values = df.iloc[x].values.tolist()
    if df['Player'][x] == 'Facundo Medina':
      c_values = df.iloc[x].values.tolist()
    if df['Player'][x] == 'Leonardo Balerdi':
      d_values = df.iloc[x].values.tolist()

a_values = a_values[1:]
b_values = b_values[1:]
c_values = c_values[1:]
d_values = d_values[1:]

values = [a_values, b_values, c_values, d_values]

# %%
values
# Out:
# [['41',
#   '38',
#   '23',
#   '4',
#   '64',
#   '68.8',
#   '20',
#   '47',
#   '25',
#   '22',
#   '55',
#   '120',
#   '116'],
#  ['35',
#   '33',
#   '21',
#   '2',
#   '39',
#   '74.4',
#   '10',
#   '33',
#   '18',
#   '15',
#   '41',
#   '97',
#   '207'],
#  ['38',
#   '25',
#   '31',
#   '8',
#   '69',
#   '63.8',
#   '25',
#   '38',
#   '13',
#   '25',
#   '24',
#   '88',
#   '59'],
#  ['50',
#   '55',
#   '23',
#   '1',
#   '67',
#   '73.1',
#   '18',
#   '38',
#   '15',
#   '23',
#   '51',
#   '130',
#   '91']]

# %%
print("Ranges:", ranges)
print("Params:", params)
print("a_values:", a_values)
print("b_values:", b_values)
print("c_values:", c_values)
print("d_values:", d_values)

print("Types in ranges:", [(type(a), type(b)) for a, b in ranges])
print("Types in params:", [type(p) for p in params])
print("Types in a_values:", [type(v) for v in a_values])
print("Types in b_values:", [type(v) for v in b_values])
print("Types in c_values:", [type(v) for v in c_values])
print("Types in d_values:", [type(v) for v in d_values])
# Out:
# Ranges: [(26.25, 62.5), (18.75, 68.75), (15.75, 38.75), (0.75, 10.0), (29.25, 86.25), (47.849999999999994, 93.0), (7.5, 31.25), (24.75, 58.75), (9.75, 31.25), (11.25, 31.25), (18.0, 68.75), (66.0, 162.5), (44.25, 258.75)]
# Params: ['TklW', 'Def 3rd', 'Mid 3rd', 'Att 3rd', 'Att', 'Tkl%', 'Lost', 'Blocks', 'Sh', 'Pass', 'Int', 'Tkl+Int', 'Clr']
# a_values: ['41', '38', '23', '4', '64', '68.8', '20', '47', '25', '22', '55', '120', '116']
# b_values: ['35', '33', '21', '2', '39', '74.4', '10', '33', '18', '15', '41', '97', '207']
# c_values: ['38', '25', '31', '8', '69', '63.8', '25', '38', '13', '25', '24', '88', '59']
# d_values: ['50', '55', '23', '1', '67', '73.1', '18', '38', '15', '23', '51', '130', '91']
# ...

# %%
ranges = [(float(a), float(b)) for a, b in ranges]

# %%
a_values = [float(i) for i in a_values if pd.notnull(i)]
b_values = [float(i) for i in b_values if pd.notnull(i)]
c_values = [float(i) for i in c_values if pd.notnull(i)]
d_values = [float(i) for i in d_values if pd.notnull(i)]

# %%
#title

title = dict(
    title_name='Comparación de Defensas Centrales',
    title_color = 'red',
    subtitle_name = '5 Grandes Ligas para AC Milan',
    subtitle_color = 'red',
    title_fontsize = 18,
    subtitle_fontsize = 15,
)

endnote = 'Pablo Crespo \nvia Fbref'

# %%
# Convertir todos los valores a numérico si aún no lo son
values = [list(map(float, v)) for v in values]

# Asegurar que los valores de rango sean numéricos
range_values = [(0, 100)] * len(params)

# %%
radar = Radar()

fig,ax = radar.plot_radar(ranges=ranges,params=params,values=values,
                          radar_color=['black','red','blue','yellow'],
                          alphas=[.75,.6,.6,.5],title=title,endnote=endnote,
                          compare=True)
